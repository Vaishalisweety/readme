# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishalisweety/readme/blob/main/dataset(12_09_22).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-4ef7fe6c-747f-4182-bd81-578bdbca43ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ef7fe6c-747f-4182-bd81-578bdbca43ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving breast-cancer.csv to breast-cancer.csv

# %%
import pandas as pd
import io
 
da= pd.read_csv(io.BytesIO(uploaded['breast-cancer.csv']))
da.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
da.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
da.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
dia= pd.crosstab(index=da['diagnosis'],columns='Frequency')
dia
# Out:
# col_0      Frequency
# diagnosis
# B                357
# M                212

# %%
sns.histplot(x='diagnosis',data=da)

# %%
ra= pd.crosstab(index=da['radius_mean'],columns='Frequency')
ra
# Out:
# col_0        Frequency
# radius_mean
# 6.981                1
# 7.691                1
# 7.729                1
# 7.760                1
# 8.196                1
# ...                ...
# 25.220               1
# 25.730               1
# 27.220               1
# 27.420               1
# 28.110               1
#
# [456 rows x 1 columns]

# %%
sns.histplot(x='radius_mean',data=da)

# %%
tx= pd.crosstab(index=da['texture_mean'],columns='Frequency')
tx
# Out:
# col_0         Frequency
# texture_mean
# 9.71                  1
# 10.38                 1
# 10.72                 1
# 10.82                 1
# 10.89                 1
# ...                 ...
# 31.12                 1
# 32.47                 1
# 33.56                 1
# 33.81                 1
# 39.28                 1
#
# [479 rows x 1 columns]

# %%
sns.histplot(x='texture_mean',data=da)

# %%
pr= pd.crosstab(index=da['perimeter_mean'],columns='Frequency')
pr
# Out:
# col_0           Frequency
# perimeter_mean
# 43.79                   1
# 47.92                   1
# 47.98                   1
# 48.34                   1
# 51.71                   1
# ...                   ...
# 171.50                  1
# 174.20                  1
# 182.10                  1
# 186.90                  1
# 188.50                  1
#
# [522 rows x 1 columns]

# %%
sns.histplot(x='perimeter_mean',data=da)

# %%
ar= pd.crosstab(index=da['area_mean'],columns='Frequency')
ar
# Out:
# col_0      Frequency
# area_mean
# 143.5              1
# 170.4              1
# 178.8              1
# 181.0              1
# 201.9              1
# ...              ...
# 1878.0             1
# 2010.0             1
# 2250.0             1
# 2499.0             1
# 2501.0             1
#
# [539 rows x 1 columns]

# %%
sns.histplot(x='area_mean',data=da)

# %%
sm= pd.crosstab(index=da['smoothness_mean'],columns='Frequency')
sm
# Out:
# col_0            Frequency
# smoothness_mean
# 0.05263                  1
# 0.06251                  1
# 0.06429                  1
# 0.06576                  1
# 0.06613                  1
# ...                    ...
# 0.13710                  1
# 0.13980                  1
# 0.14250                  1
# 0.14470                  1
# 0.16340                  1
#
# [474 rows x 1 columns]

# %%
sns.histplot(x='smoothness_mean',data=da)

# %%
co= pd.crosstab(index=da['compactness_mean'],columns='Frequency')
co
# Out:
# col_0             Frequency
# compactness_mean
# 0.01938                   1
# 0.02344                   1
# 0.02650                   1
# 0.02675                   1
# 0.03116                   1
# ...                     ...
# 0.28320                   1
# 0.28390                   1
# 0.28670                   1
# 0.31140                   1
# 0.34540                   1
#
# [537 rows x 1 columns]

# %%
sns.histplot(x='compactness_mean',data=da)

# %%
con= pd.crosstab(index=da['concavity_mean'],columns='Frequency')
con
# Out:
# col_0           Frequency
# concavity_mean
# 0.000000               13
# 0.000692                1
# 0.000974                1
# 0.001194                1
# 0.001461                1
# ...                   ...
# 0.363500                1
# 0.375400                1
# 0.410800                1
# 0.426400                1
# 0.426800                1
#
# [537 rows x 1 columns]

# %%
sns.histplot(x='concavity_mean',data=da)

# %%
conc= pd.crosstab(index=da['concave points_mean'],columns='Frequency')
conc
# Out:
# col_0                Frequency
# concave points_mean
# 0.000000                    13
# 0.001852                     1
# 0.002404                     1
# 0.002924                     1
# 0.002941                     1
# ...                        ...
# 0.182300                     1
# 0.184500                     1
# 0.187800                     1
# 0.191300                     1
# 0.201200                     1
#
# [542 rows x 1 columns]

# %%
sns.histplot(x='concave points_mean',data=da)

# %%
sy= pd.crosstab(index=da['symmetry_mean'],columns='Frequency')
sy
# Out:
# col_0          Frequency
# symmetry_mean
# 0.1060                 1
# 0.1167                 1
# 0.1203                 1
# 0.1215                 1
# 0.1220                 1
# ...                  ...
# 0.2655                 1
# 0.2678                 1
# 0.2743                 1
# 0.2906                 1
# 0.3040                 1
#
# [432 rows x 1 columns]

# %%
sns.histplot(x='symmetry_mean',data=da)

# %%
fr= pd.crosstab(index=da['fractal_dimension_mean'],columns='Frequency')
fr
# Out:
# col_0                   Frequency
# fractal_dimension_mean
# 0.04996                         1
# 0.05024                         1
# 0.05025                         1
# 0.05044                         1
# 0.05054                         1
# ...                           ...
# 0.08980                         1
# 0.09296                         1
# 0.09502                         1
# 0.09575                         1
# 0.09744                         1
#
# [499 rows x 1 columns]

# %%
sns.histplot(x='fractal_dimension_mean',data=da)

# %%
rad= pd.crosstab(index=da['radius_se'],columns='Frequency')
rad
# Out:
# col_0      Frequency
# radius_se
# 0.1115             1
# 0.1144             1
# 0.1153             1
# 0.1166             1
# 0.1186             1
# ...              ...
# 1.2960             1
# 1.3700             1
# 1.5090             1
# 2.5470             1
# 2.8730             1
#
# [540 rows x 1 columns]

# %%
sns.histplot(x='radius_se',data=da)

# %%
text= pd.crosstab(index=da['texture_se'],columns='Frequency')
text
# Out:
# col_0       Frequency
# texture_se
# 0.3602              1
# 0.3621              1
# 0.3628              1
# 0.3871              1
# 0.3981              1
# ...               ...
# 3.1200              1
# 3.5680              1
# 3.6470              1
# 3.8960              1
# 4.8850              1
#
# [519 rows x 1 columns]

# %%
sns.histplot(x='texture_se',data=da)

# %%
per= pd.crosstab(index=da['perimeter_se'],columns='Frequency')
per
# Out:
# col_0         Frequency
# perimeter_se
# 0.7570                1
# 0.7714                1
# 0.8439                1
# 0.8484                1
# 0.8730                1
# ...                 ...
# 10.0500               1
# 10.1200               1
# 11.0700               1
# 18.6500               1
# 21.9800               1
#
# [533 rows x 1 columns]

# %%
sns.histplot(x='perimeter_se',data=da)

# %%
area= pd.crosstab(index=da['area_se'],columns='Frequency')
area
# Out:
# col_0    Frequency
# area_se
# 6.802            1
# 7.228            1
# 7.254            1
# 7.326            1
# 8.205            1
# ...            ...
# 199.700          1
# 224.100          1
# 233.000          1
# 525.600          1
# 542.200          1
#
# [528 rows x 1 columns]

# %%
sns.histplot(x='area_se',data=da)

# %%
smoo= pd.crosstab(index=da['smoothness_se'],columns='Frequency')
smoo
# Out:
# col_0          Frequency
# smoothness_se
# 0.001713               1
# 0.002667               1
# 0.002826               1
# 0.002838               1
# 0.002866               1
# ...                  ...
# 0.018350               1
# 0.020750               1
# 0.021770               1
# 0.023330               1
# 0.031130               1
#
# [547 rows x 1 columns]

# %%
sns.histplot(x='smoothness_se',data=da)

# %%
comp= pd.crosstab(index=da['compactness_se'],columns='Frequency')
comp
# Out:
# col_0           Frequency
# compactness_se
# 0.002252                1
# 0.003012                1
# 0.003710                1
# 0.003746                1
# 0.004660                1
# ...                   ...
# 0.095860                1
# 0.098060                1
# 0.100600                1
# 0.106400                1
# 0.135400                1
#
# [541 rows x 1 columns]

# %%
sns.histplot(x='compactness_se',data=da)

# %%
conc= pd.crosstab(index=da['concavity_se'],columns='Frequency')
conc
# Out:
# col_0         Frequency
# concavity_se
# 0.000000             13
# 0.000692              1
# 0.000793              1
# 0.000974              1
# 0.001128              1
# ...                 ...
# 0.143500              1
# 0.143800              1
# 0.153500              1
# 0.303800              1
# 0.396000              1
#
# [533 rows x 1 columns]

# %%
sns.histplot(x='concavity_se',data=da)

# %%
conca= pd.crosstab(index=da['concave points_se'],columns='Frequency')
conca
# Out:
# col_0              Frequency
# concave points_se
# 0.000000                  13
# 0.001852                   1
# 0.002386                   1
# 0.002404                   1
# 0.002924                   1
# ...                      ...
# 0.034410                   1
# 0.034870                   1
# 0.039270                   1
# 0.040900                   1
# 0.052790                   1
#
# [507 rows x 1 columns]

# %%
sns.histplot(x='concave points_se',data=da)

# %%
sym= pd.crosstab(index=da['symmetry_se'],columns='Frequency')
sym
# Out:
# col_0        Frequency
# symmetry_se
# 0.007882             1
# 0.009539             1
# 0.009947             1
# 0.010130             1
# 0.010290             1
# ...                ...
# 0.055430             1
# 0.056280             1
# 0.059630             1
# 0.061460             1
# 0.078950             1
#
# [498 rows x 1 columns]

# %%
sns.histplot(x='symmetry_se',data=da)

# %%
fra= pd.crosstab(index=da['fractal_dimension_se'],columns='Frequency')
fra
# Out:
# col_0                 Frequency
# fractal_dimension_se
# 0.000895                      1
# 0.000950                      1
# 0.000968                      1
# 0.001002                      1
# 0.001058                      1
# ...                         ...
# 0.012980                      1
# 0.017920                      1
# 0.021930                      1
# 0.022860                      1
# 0.029840                      1
#
# [545 rows x 1 columns]

# %%
sns.histplot(x='fractal_dimension_se',data=da)

# %%
radius= pd.crosstab(index=da['radius_worst'],columns='Frequency')
radius
# Out:
# col_0         Frequency
# radius_worst
# 7.930                 1
# 8.678                 1
# 8.952                 1
# 8.964                 1
# 9.077                 1
# ...                 ...
# 31.010                1
# 32.490                1
# 33.120                1
# 33.130                1
# 36.040                1
#
# [457 rows x 1 columns]

# %%
sns.histplot(x='radius_worst',data=da)

# %%
texture= pd.crosstab(index=da['texture_worst'],columns='Frequency')
texture
# Out:
# col_0          Frequency
# texture_worst
# 12.02                  1
# 12.49                  1
# 12.87                  1
# 14.10                  1
# 14.20                  1
# ...                  ...
# 42.79                  1
# 44.87                  1
# 45.41                  1
# 47.16                  1
# 49.54                  1
#
# [511 rows x 1 columns]

# %%
sns.histplot(x='texture_worst',data=da)

# %%
perimeter= pd.crosstab(index=da['perimeter_worst'],columns='Frequency')
perimeter
# Out:
# col_0            Frequency
# perimeter_worst
# 50.41                    1
# 54.49                    1
# 56.65                    1
# 57.17                    1
# 57.26                    1
# ...                    ...
# 211.70                   1
# 214.00                   1
# 220.80                   1
# 229.30                   1
# 251.20                   1
#
# [514 rows x 1 columns]

# %%
sns.histplot(x='perimeter_worst',data=da)

# %%
areas= pd.crosstab(index=da['area_worst'],columns='Frequency')
areas
# Out:
# col_0       Frequency
# area_worst
# 185.2               1
# 223.6               1
# 240.1               1
# 242.2               1
# 248.0               1
# ...               ...
# 3143.0              1
# 3216.0              1
# 3234.0              1
# 3432.0              1
# 4254.0              1
#
# [544 rows x 1 columns]

# %%
sns.histplot(x='area_worst',data=da)

# %%
smooth= pd.crosstab(index=da['smoothness_worst'],columns='Frequency')
smooth
# Out:
# col_0             Frequency
# smoothness_worst
# 0.07117                   1
# 0.08125                   1
# 0.08409                   1
# 0.08484                   1
# 0.08567                   1
# ...                     ...
# 0.19090                   1
# 0.20060                   1
# 0.20980                   1
# 0.21840                   1
# 0.22260                   1
#
# [411 rows x 1 columns]

# %%
sns.histplot(x='smoothness_worst',data=da)

# %%
compact= pd.crosstab(index=da['compactness_worst'],columns='Frequency')
compact
# Out:
# col_0              Frequency
# compactness_worst
# 0.02729                    1
# 0.03432                    1
# 0.04327                    1
# 0.04619                    1
# 0.04712                    1
# ...                      ...
# 0.86630                    1
# 0.86810                    1
# 0.93270                    1
# 0.93790                    1
# 1.05800                    1
#
# [529 rows x 1 columns]

# %%
sns.histplot(x='compactness_worst',data=da)

# %%
concavity= pd.crosstab(index=da['concavity_worst'],columns='Frequency')
concavity
# Out:
# col_0            Frequency
# concavity_worst
# 0.000000                13
# 0.001845                 1
# 0.003581                 1
# 0.004955                 1
# 0.005518                 1
# ...                    ...
# 0.938700                 1
# 0.960800                 1
# 1.105000                 1
# 1.170000                 1
# 1.252000                 1
#
# [539 rows x 1 columns]

# %%
sns.histplot(x='concavity_worst',data=da)

# %%
concave= pd.crosstab(index=da['concave points_worst'],columns='Frequency')
concave
# Out:
# col_0                 Frequency
# concave points_worst
# 0.000000                     13
# 0.008772                      1
# 0.009259                      1
# 0.010420                      1
# 0.011110                      2
# ...                         ...
# 0.273300                      1
# 0.275600                      1
# 0.286700                      1
# 0.290300                      1
# 0.291000                      1
#
# [492 rows x 1 columns]

# %%
sns.histplot(x='concave points_worst',data=da)

# %%
symmetry= pd.crosstab(index=da['symmetry_worst'],columns='Frequency')
symmetry
# Out:
# col_0           Frequency
# symmetry_worst
# 0.1565                  1
# 0.1566                  1
# 0.1603                  1
# 0.1648                  1
# 0.1652                  1
# ...                   ...
# 0.5166                  1
# 0.5440                  1
# 0.5558                  1
# 0.5774                  1
# 0.6638                  1
#
# [500 rows x 1 columns]

# %%
sns.histplot(x='symmetry_worst',data=da)

# %%
fractal= pd.crosstab(index=da['fractal_dimension_worst'],columns='Frequency')
fractal
# Out:
# col_0                    Frequency
# fractal_dimension_worst
# 0.05504                          1
# 0.05521                          1
# 0.05525                          1
# 0.05695                          1
# 0.05737                          1
# ...                            ...
# 0.14310                          1
# 0.14460                          1
# 0.14860                          1
# 0.17300                          1
# 0.20750                          1
#
# [535 rows x 1 columns]

# %%
sns.histplot(x='fractal_dimension_worst',data=da)
